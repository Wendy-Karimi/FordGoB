# %% [markdown]
# # Part I - Ford GoBike System Data
# ## by Wendy Karimi Patrick
#
# # Table of contents
# 1. [Introduction](#Introduction)
# 2. [Preliminary Wrangling](#Preliminary_Wrangling)
#
# 3. [Univariate Exploration](#Univariate_Exploration)
#
# 4. [Bivariate Exploration](#Bivariate_Exploration)
#
# 5. [Multivariate Exploration](#Multivariate_Exploration)
#
# 6. [Conclusion](#Conclusions)

# %% [markdown]
# ## Introduction
# This dataset includes information about individual rides made in a bike sharing system covering the greater San Francisco Bay area. It contains different specifications which will greatly help in the analysis.
#
#
#
#
# ## Preliminary_Wrangling

# %%
# import all packages and set plots to be embedded inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %matplotlib inline

# %%
Go_Bike=pd.read_csv('Ford GoBike System Data.csv')

# %%
Go_Bike
# Out:
#         duration_sec                start_time                  end_time  \
# 0              52185  2019-02-28 17:32:10.1450  2019-03-01 08:01:55.9750
# 1              42521  2019-02-28 18:53:21.7890  2019-03-01 06:42:03.0560
# 2              61854  2019-02-28 12:13:13.2180  2019-03-01 05:24:08.1460
# 3              36490  2019-02-28 17:54:26.0100  2019-03-01 04:02:36.8420
# 4               1585  2019-02-28 23:54:18.5490  2019-03-01 00:20:44.0740
# 5               1793  2019-02-28 23:49:58.6320  2019-03-01 00:19:51.7600
# 6               1147  2019-02-28 23:55:35.1040  2019-03-01 00:14:42.5880
# 7               1615  2019-02-28 23:41:06.7660  2019-03-01 00:08:02.7560
# 8               1570  2019-02-28 23:41:48.7900  2019-03-01 00:07:59.7150
# 9               1049  2019-02-28 23:49:47.6990  2019-03-01 00:07:17.0250
# 10               458  2019-02-28 23:57:57.2110  2019-03-01 00:05:35.4350
# 11               506  2019-02-28 23:56:55.5400  2019-03-01 00:05:21.7330
# ...

# %%
print(Go_Bike.head())
print(Go_Bike.shape)
# Out:
#    duration_sec                start_time                  end_time  \
# 0         52185  2019-02-28 17:32:10.1450  2019-03-01 08:01:55.9750
# 1         42521  2019-02-28 18:53:21.7890  2019-03-01 06:42:03.0560
# 2         61854  2019-02-28 12:13:13.2180  2019-03-01 05:24:08.1460
# 3         36490  2019-02-28 17:54:26.0100  2019-03-01 04:02:36.8420
# 4          1585  2019-02-28 23:54:18.5490  2019-03-01 00:20:44.0740
#
#    start_station_id                                start_station_name  \
# 0              21.0  Montgomery St BART Station (Market St at 2nd St)
# 1              23.0                     The Embarcadero at Steuart St
# 2              86.0                           Market St at Dolores St
# 3             375.0                           Grove St at Masonic Ave
# 4               7.0                               Frank H Ogawa Plaza
#
#    start_station_latitude  start_station_longitude  end_station_id  \
# ...

# %%
Go_Bike.describe()
# Out:
#         duration_sec  start_station_id  start_station_latitude  \
# count  183412.000000     183215.000000           183412.000000
# mean      726.078435        138.590427               37.771223
# std      1794.389780        111.778864                0.099581
# min        61.000000          3.000000               37.317298
# 25%       325.000000         47.000000               37.770083
# 50%       514.000000        104.000000               37.780760
# 75%       796.000000        239.000000               37.797280
# max     85444.000000        398.000000               37.880222
#
#        start_station_longitude  end_station_id  end_station_latitude  \
# count            183412.000000   183215.000000         183412.000000
# mean               -122.352664      136.249123             37.771427
# std                   0.117097      111.515131              0.099490
# min                -122.453704        3.000000             37.317298
# ...

# %%
Go_Bike.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183412 entries, 0 to 183411
# Data columns (total 16 columns):
# duration_sec               183412 non-null int64
# start_time                 183412 non-null object
# end_time                   183412 non-null object
# start_station_id           183215 non-null float64
# start_station_name         183215 non-null object
# start_station_latitude     183412 non-null float64
# start_station_longitude    183412 non-null float64
# end_station_id             183215 non-null float64
# end_station_name           183215 non-null object
# end_station_latitude       183412 non-null float64
# end_station_longitude      183412 non-null float64
# bike_id                    183412 non-null int64
# user_type                  183412 non-null object
# member_birth_year          175147 non-null float64
# member_gender              175147 non-null object
# bike_share_for_all_trip    183412 non-null object
# dtypes: float64(7), int64(2), object(7)
# ...

# %%
#drop rows with Null values
Go_Bike.dropna(inplace=True)

# %%
Go_Bike['member_gender'].value_counts()
# Out:
# Male      130500
# Female     40805
# Other       3647
# Name: member_gender, dtype: int64

# %%
Go_Bike['start_station_name'].value_counts()
# Out:
# Market St at 10th St                                               3649
# San Francisco Caltrain Station 2  (Townsend St at 4th St)          3408
# Berry St at 4th St                                                 2952
# Montgomery St BART Station (Market St at 2nd St)                   2711
# Powell St BART Station (Market St at 4th St)                       2620
# San Francisco Caltrain (Townsend St at 4th St)                     2577
# San Francisco Ferry Building (Harry Bridges Plaza)                 2541
# Howard St at Beale St                                              2216
# Steuart St at Market St                                            2191
# Powell St BART Station (Market St at 5th St)                       2144
# The Embarcadero at Sansome St                                      1975
# Bancroft Way at Telegraph Ave                                      1761
# Bancroft Way at College Ave                                        1712
# ...

# %%
Go_Bike['end_station_name'].value_counts()
# Out:
# San Francisco Caltrain Station 2  (Townsend St at 4th St)          4624
# Market St at 10th St                                               3709
# Montgomery St BART Station (Market St at 2nd St)                   3461
# San Francisco Ferry Building (Harry Bridges Plaza)                 3151
# San Francisco Caltrain (Townsend St at 4th St)                     2870
# Powell St BART Station (Market St at 4th St)                       2854
# Berry St at 4th St                                                 2782
# The Embarcadero at Sansome St                                      2341
# Steuart St at Market St                                            2264
# Powell St BART Station (Market St at 5th St)                       2153
# Howard St at Beale St                                              1970
# Beale St at Harrison St                                            1780
# Bancroft Way at Telegraph Ave                                      1780
# ...

# %%
Go_Bike['member_birth_year'].value_counts()
# Out:
# 1988.0    10214
# 1993.0     9323
# 1989.0     8967
# 1990.0     8640
# 1991.0     8484
# 1992.0     8245
# 1987.0     8010
# 1986.0     7953
# 1994.0     7654
# 1995.0     7420
# 1985.0     7023
# 1984.0     6557
# 1983.0     5953
# 1980.0     5011
# 1982.0     4987
# 1996.0     4637
# 1981.0     4344
# 1979.0     3756
# 1997.0     3476
# 1998.0     3208
# 1978.0     2830
# 1977.0     2706
# 1974.0     2633
# 1999.0     2504
# 1975.0     2503
# 1976.0     2435
# 1973.0     2080
# 1968.0     1927
# 1971.0     1924
# 1972.0     1909
#           ...
# 1954.0      301
# 1952.0      189
# 1951.0      180
# 1950.0      178
# 1953.0      158
# 1947.0      135
# 1955.0      134
# 1945.0      105
# 1949.0       99
# 1931.0       89
# 1900.0       53
# 1948.0       51
# 2001.0       34
# 1943.0       30
# 1942.0       21
# 1933.0       20
# 1946.0       19
# 1902.0       11
# 1939.0       11
# 1941.0        9
# 1901.0        6
# 1938.0        3
# 1920.0        3
# 1934.0        2
# ...

# %%
Go_Bike['bike_share_for_all_trip'].value_counts()
# Out:
# No     157606
# Yes     17346
# Name: bike_share_for_all_trip, dtype: int64

# %%
Go_Bike['member_gender'].value_counts()
# Out:
# Male      130500
# Female     40805
# Other       3647
# Name: member_gender, dtype: int64

# %%
# import pandas as pd

# # Example dataframe
# df = pd.DataFrame({'col1': [1.0, 2.0, 3.0, float('nan'), float('inf')]})

# Drop  inf values
Go_Bike.replace([np.inf, -np.inf], inplace=True)
Go_Bike.dropna(subset=['member_birth_year'], inplace=True)
#Go_Bike= Go_Bike[~Go_Bike['member_birth_year'].isin([np.inf, -np.inf])]

# # Convert float to integer
# df['col1'] = df['col1'].astype(int)

# %%
# Convert member birth year to integer datatype
Go_Bike.member_birth_year = Go_Bike.member_birth_year.astype('int64')

# %%
# convert end and start time to datetime datatype
Go_Bike.end_time = Go_Bike.end_time.astype('datetime64')
Go_Bike.start_time = Go_Bike.start_time.astype('datetime64')

# %%
Go_Bike.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 174952 entries, 0 to 183411
# Data columns (total 16 columns):
# duration_sec               174952 non-null int64
# start_time                 174952 non-null datetime64[ns]
# end_time                   174952 non-null datetime64[ns]
# start_station_id           174952 non-null float64
# start_station_name         174952 non-null object
# start_station_latitude     174952 non-null float64
# start_station_longitude    174952 non-null float64
# end_station_id             174952 non-null float64
# end_station_name           174952 non-null object
# end_station_latitude       174952 non-null float64
# end_station_longitude      174952 non-null float64
# bike_id                    174952 non-null int64
# user_type                  174952 non-null object
# member_birth_year          174952 non-null int64
# member_gender              174952 non-null object
# bike_share_for_all_trip    174952 non-null object
# ...

# %%
# Create separate date and time columns for both start and end times.
Go_Bike['Start_date'] = Go_Bike['start_time'].dt.date
Go_Bike['Start_time'] = Go_Bike['start_time'].dt.time
Go_Bike['End_date'] = Go_Bike['end_time'].dt.date
Go_Bike['End_time'] = Go_Bike['end_time'].dt.time

# %%
Go_Bike.head(3)
# Out:
#    duration_sec              start_time                end_time  \
# 0         52185 2019-02-28 17:32:10.145 2019-03-01 08:01:55.975
# 2         61854 2019-02-28 12:13:13.218 2019-03-01 05:24:08.146
# 3         36490 2019-02-28 17:54:26.010 2019-03-01 04:02:36.842
#
#    start_station_id                                start_station_name  \
# 0              21.0  Montgomery St BART Station (Market St at 2nd St)
# 2              86.0                           Market St at Dolores St
# 3             375.0                           Grove St at Masonic Ave
#
#    start_station_latitude  start_station_longitude  end_station_id  \
# 0               37.789625              -122.400811            13.0
# 2               37.769305              -122.426826             3.0
# 3               37.774836              -122.446546            70.0
#
#                                end_station_name  end_station_latitude  \
# 0                Commercial St at Montgomery St             37.794231
# ...

# %%
#Go_Bike.loc[:,'Lead_Time'] = 'end_time' - 'start_time'
Go_Bike['Lead_Time'] = Go_Bike['End_date'] - Go_Bike['Start_date'] 
#Go_Bike['Lead_Time'] = Lead_time

# %%
Go_Bike.head(5)
# Out:
#    duration_sec              start_time                end_time  \
# 0         52185 2019-02-28 17:32:10.145 2019-03-01 08:01:55.975
# 2         61854 2019-02-28 12:13:13.218 2019-03-01 05:24:08.146
# 3         36490 2019-02-28 17:54:26.010 2019-03-01 04:02:36.842
# 4          1585 2019-02-28 23:54:18.549 2019-03-01 00:20:44.074
# 5          1793 2019-02-28 23:49:58.632 2019-03-01 00:19:51.760
#
#    start_station_id                                start_station_name  \
# 0              21.0  Montgomery St BART Station (Market St at 2nd St)
# 2              86.0                           Market St at Dolores St
# 3             375.0                           Grove St at Masonic Ave
# 4               7.0                               Frank H Ogawa Plaza
# 5              93.0                      4th St at Mission Bay Blvd S
#
#    start_station_latitude  start_station_longitude  end_station_id  \
# 0               37.789625              -122.400811            13.0
# ...

# %%
Go_Bike.Lead_Time.value_counts()
# Out:
# 0 days    174669
# 1 days       283
# Name: Lead_Time, dtype: int64

# %% [markdown]
# ####  Most rides have a lead time of less than 1 day. Only 283 rides had a lead time of more than one day.

# %%
# import pandas as pd

# # create a sample dataframe with time
# df = pd.DataFrame({'time': ['10:00:00', '11:30:00', '12:45:00']})

# # convert the time column to a datetime object
# df['time'] = pd.to_datetime(df['time'], format='%H:%M:%S').dt.time

# # extract the hour component of the time
# df['hour'] = df['time'].apply(lambda x: x.hour)

# # drop the original time column
# df = df.drop('time', axis=1)

# # display the updated dataframe
# print(df)

# %%
Go_Bike.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 174952 entries, 0 to 183411
# Data columns (total 21 columns):
# duration_sec               174952 non-null int64
# start_time                 174952 non-null datetime64[ns]
# end_time                   174952 non-null datetime64[ns]
# start_station_id           174952 non-null float64
# start_station_name         174952 non-null object
# start_station_latitude     174952 non-null float64
# start_station_longitude    174952 non-null float64
# end_station_id             174952 non-null float64
# end_station_name           174952 non-null object
# end_station_latitude       174952 non-null float64
# end_station_longitude      174952 non-null float64
# bike_id                    174952 non-null int64
# user_type                  174952 non-null object
# member_birth_year          174952 non-null int64
# member_gender              174952 non-null object
# bike_share_for_all_trip    174952 non-null object
# ...

# %%
# import pandas as pd

# # create a sample dataframe with start and end times
# df = pd.DataFrame({'start_time': ['2021-01-01 10:00:00', '2021-01-02 11:30:00', '2021-01-03 12:45:00'],
#                    'end_time': ['2021-01-01 12:00:00', '2021-01-02 14:00:00', '2021-01-03 15:00:00']})

# # convert the start and end time columns to datetime objects
# df['start_time'] = pd.to_datetime(df['start_time'])
# df['end_time'] = pd.to_datetime(df['end_time'])

# # calculate the lead time as the difference between end and start time
# df['lead_time'] = df['end_time'] - df['start_time']

# # display the updated dataframe
# print(df)

# %% [markdown]
# ### What_is_the_structure_of_your_dataset?
#
# The dataset contains 16 specifications which consists of information regarding 183412 trips of bike rides. Out of the 16 specifications in the dataset, 7 are float, 2 are integer and 7 are object datatype. There are null values which I'll need to drop inorder to have a cleaner dataset. In my dataset I have rows for gender , the time duration with start and end times. There is also the user type column which is either consumer or subscriber. There is a column indicating whether the bike was shared or not. Start and end stations are also in the dataset with their longitudes and latitudes.
#
# ### What_is/are_the_main_feature(s)_of _interest_in_your_dataset?
#
# The main features of interest in my dataset are the bike sharing, member gender, user type, the bike riding duration(Sec) and members birth years.
#
# ### What features in the dataset do you think will help support your investigation into your feature(s) of interest?
#  The bike riding duration and member gender.

# %% [markdown]
# ## Univariate_Exploration

# %% [markdown]
# ### What is the  sum and percentage of the different member gender in the dataset?

# %%
Gender_Counts = Go_Bike['member_gender'].value_counts()

plt.pie(Gender_Counts, labels = Gender_Counts.index, startangle = 45,
        counterclock = False, wedgeprops = {'width' : 0.6});

plt.legend(Gender_Counts)
plt.title('Sum of member gender')
plt.axis('square');

# plt.subplot(1,2,2)
# Gender_Counts = Go_Bike['member_gender'].value_counts()
# total = sum(Gender_Counts)
# data_per = Gender_Counts /total*100
# plt.pie(data_per, labels = [round(i,2) for i in (list(data_per))])
# circle = plt.Circle( (0,0), 0.4, color='white')
# p=plt.gcf()
# p.gca().add_artist(circle)
# plt.axis('equal')
# plt.tight_layout()
# plt.show()

# %% [markdown]
# #### There are 130,500 males, 40805 female and other gender was 3647

# %%
Go_Bike['member_gender'].value_counts().plot(kind='pie',title='Percentage of member gender',figsize=(5,5),autopct="%2.1f%%")
#def func(pct, allvalues):
    #absolute = int(pct / 100.*np.sum(allvalues))
    #return "{:.1f}%\n({:d} g)".format(pct, absolute)
 
plt.legend();

# %% [markdown]
# ####   There are more men than women. Of the total participants in the bike riding, 74.59% were men, 23.32% were female and other was 2.08%

# %%
# import numpy as np
# Gender_Counts = Go_Bike['member_gender'].value_counts()
# total = sum(Gender_Counts)
# data_per = Gender_Counts /total*100
# plt.pie(data_per, labels = [round(i,2) for i in (list(data_per))])
# circle = plt.Circle( (0,0), 0.4, color='white')
# p=plt.gcf()
# p.gca().add_artist(circle)
# plt.legend()
# plt.axis('equal')
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ### What are the common birth years of the members?

# %%
def bar_chart_solution_1():
    
    plt.figure(figsize = [15,8])
    year_order = [1985,1986,1987, 1989,1990, 1991,1992,1993,1994,1995]
    base_color = sb.color_palette()[5]
#Go_Bike.member_birth_year.value_counts()[1:11].plot('bar', figsize=(10,6) , color= base_color)
                                 
    sb.countplot(data=Go_Bike, x='member_birth_year', color=base_color, order=year_order );

    plt.xlabel('Years')
    plt.ylabel('Number of Riders');
    plt.title('Top 10 members birth years');
 #plt.savefig(names)
bar_chart_solution_1()

# %% [markdown]
# #### Most  of the members were born between 1985 and 1995.

# %% [markdown]
# ### The distribution of members'  ages

# %%
Go_Bike['Start_date'] = Go_Bike['Start_date'].astype('datetime64')
Go_Bike['year'] = Go_Bike['Start_date'].apply(lambda x: x.year)

# %%
#Go_Bike.year.value_counts()
Go_Bike['Start_date'].dt.year.unique()
# Out:
# array([2019])

# %% [markdown]
# #### All the data collected was for the year 2019 only.

# %%
# Create new column containing the members' ages
Go_Bike['Members_Age'] = Go_Bike['year'] - Go_Bike['member_birth_year']

# %%
# Sort the ages in ascending order.
Go_Bike['Members_Age'].value_counts().sort_index()
# Out:
# 18        34
# 19      1675
# 20      2504
# 21      3208
# 22      3476
# 23      4637
# 24      7420
# 25      7654
# 26      9323
# 27      8245
# 28      8484
# 29      8640
# 30      8967
# 31     10214
# 32      8010
# 33      7953
# 34      7023
# 35      6557
# 36      5953
# 37      4987
# 38      4344
# 39      5011
# 40      3756
# 41      2830
# 42      2706
# 43      2435
# 44      2503
# 45      2633
# 46      2080
# 47      1909
#        ...
# 63       392
# 64       134
# 65       301
# 66       158
# 67       189
# 68       180
# 69       178
# 70        99
# 71        51
# 72       135
# 73        19
# 74       105
# 75         2
# 76        30
# 77        21
# 78         9
# 80        11
# 81         3
# 85         2
# 86        20
# 88        89
# 89         1
# 91         1
# 92         1
# 99         3
# 109        1
# 117       11
# 118        6
# 119       53
# 141        1
# Name: Members_Age, Length: 75, dtype: int64

# %%
# base_color = sb.color_palette()[0]
# Go_Bike.Members_Age.value_counts()[0:16].plot('bar', figsize=(12,5), title='Top 15 members age', color= base_color)
plt.hist(data = Go_Bike, x = 'Members_Age', bins = 20)
plt.xlabel('Members_Age')
plt.ylabel('Number of riders')
plt.title('Distribution of members age');

# %% [markdown]
# #### Most of the riders are between 20 - 40 years. The members ages are skewed to the right.

# %% [markdown]
# ### What are the bottom 15 ages of the riders?

# %%
def bar_chart_solution_2():
   
    base_color = sb.color_palette()[0]
    Go_Bike.Members_Age.value_counts()[65:76].plot('bar', figsize=(12,5), title='Bottom 10 members age', color= base_color)
    plt.xlabel('Members_Age')
    plt.ylabel('Number of riders');

bar_chart_solution_2()

# %% [markdown]
# ####  Most of the riders of the trip are young people with the youngest riders being 18 years and the oldest member being 141 years. Most of the riders are  31 years.

# %% [markdown]
# ## Detemining the bike share ratios

# %%
Share_counts = Go_Bike['bike_share_for_all_trip'].value_counts()
Share_counts
# Out:
# No     157606
# Yes     17346
# Name: bike_share_for_all_trip, dtype: int64

# %%
total = sum(Share_counts)
data_per = Share_counts/total*100
print (data_per)
# Out:
# No     90.085281
# Yes     9.914719
# Name: bike_share_for_all_trip, dtype: float64

# %%
Share_counts = Go_Bike['bike_share_for_all_trip'].value_counts()
labels = [r' No(90.09 %)', r' Yes (9.91 %)']
colors = ['lightcoral', 'lightskyblue']
patches, texts = plt.pie(Share_counts, startangle = 90, colors=colors,counterclock = False)
plt.legend(patches,labels,loc="best")
plt.axis('equal')
plt.tight_layout()
plt.title('Percentage of bike share')
plt.show();

# %%
# Go_Bike['bike_share_for_all_trip'].value_counts().plot(kind='pie',title='percentage of males and females',figsize=(5,5),autopct="%2.1f%%")
# #def func(pct, allvalues):
#     #absolute = int(pct / 100.*np.sum(allvalues))
#     #return "{:.1f}%\n({:d} g)".format(pct, absolute)
 
# plt.legend()

# %% [markdown]
# #### Of the trips made 9.91% of all the bikes were shared and 90.09% of he bikes used were not shared during the trip.

# %% [markdown]
# ### Which is the most common start station.

# %%
def bar_chart_solution_3(): 
    base_color = sb.color_palette()[0]
    Go_Bike.start_station_name.value_counts()[0:16].plot('barh', figsize=(12,5), title='Top 15 start station', color= base_color)
    plt.xlabel('Number of Riders')
    plt.ylabel('Station Name');
    
bar_chart_solution_3()

# %% [markdown]
# #### The most common start station is market st at 10th st.

# %% [markdown]
# ### Which are least common start stations

# %%
def bar_chart_solution_4(): 
    base_color = sb.color_palette()[7]
    Go_Bike.start_station_name.value_counts()[314:330].plot('barh', figsize=(12,5), title='Bottom 15 start station', color= base_color)
    plt.xlabel('Number of Riders')
    plt.ylabel('Station Name');

bar_chart_solution_4()

# %% [markdown]
# ### Which is the most common  end station.

# %%
def bar_chart_solution_5():

    base_color = sb.color_palette()[9]
    Go_Bike.end_station_name.value_counts()[0:16].plot('bar', figsize=(12,5), title='Top 15 end station', color= base_color)
    plt.xlabel('Station Name')
    plt.ylabel('Number of Riders');

bar_chart_solution_5()

# %% [markdown]
# #### San Francisco Caltrain station 2( Townsend St at 4th St) is the most common end station and the second most common start station. All the top 10  start stations are the end stations, except for Bancroft Way at College Avenue.

# %% [markdown]
# ### Which day of the week was the most  number of bike trips made?

# %%
# Convert start date to datetime.
Go_Bike['Start_date'] = Go_Bike['Start_date'].astype('datetime64')

# %%
# Create  a weekday column.
Go_Bike['Day_of_Week'] = Go_Bike['Start_date'].dt.weekday_name

# %%
# Get the number of rides made each day.
Go_Bike.Day_of_Week.value_counts()
# Out:
# Thursday     33712
# Tuesday      30584
# Wednesday    28426
# Friday       27663
# Monday       25641
# Sunday       14512
# Saturday     14414
# Name: Day_of_Week, dtype: int64

# %%
# Plot
def bar_chart_solution_6():
    plt.figure(figsize = [10, 6])
    days_ordered = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

#Go_Bike['days_ordered'] = pd.Categorical(Go_Bike['Day_of_Week'], categories=days_ordered, ordered=True)

    base_color = sb.color_palette()[2]
    sb.countplot(data=Go_Bike, x='Day_of_Week', color=base_color,order=days_ordered);

    plt.title('Number of Riders')
    plt.xlabel('Weekday')
    plt.ylabel('Number of Riders');

bar_chart_solution_6()

# %% [markdown]
# #### Most of the rides were made on Thursday. The least number of rides were made on Saturday.

# %% [markdown]
# ### What percentage of the riders are subscriber and customer use types?

# %%
User_Counts = Go_Bike['user_type'].value_counts()
User_Counts
# Out:
# Subscriber    158386
# Customer       16566
# Name: user_type, dtype: int64

# %%
total_2 = sum(User_Counts)
User_per = User_Counts/total_2*100
print (User_per)
# Out:
# Subscriber    90.531117
# Customer       9.468883
# Name: user_type, dtype: float64

# %%
#Share_Counts = Go_Bike['user_type'].value_counts()
labels = [r' Subcriber(90.53 %)', r' Customer(9.46 %)']
colors = ['Brown', 'violet']
patches, texts = plt.pie(User_Counts, startangle = 90, colors=colors, counterclock = False)
plt.legend(patches,labels,loc="best")
plt.axis('equal')
plt.tight_layout()
plt.title('Percentage of user type')
plt.show();

# %% [markdown]
# #### Most of the users are subscribers with a percentage of customers being 9.46% and subscribers being 90.53%.

# %% [markdown]
# ### Discuss the distribution(s) of your variable(s) of interest. Were there any unusual points? Did you need to perform any transformations?
#
# The main variables of interest in my dataset are the bike sharing, member gender, user type, the bike riding duration(Sec) and members birth years. No transformation were needed
#
# ### Of the features you investigated, were there any unusual distributions? Did you perform any operations on the data to tidy, adjust, or change the form of the data? If so, why did you do this?
# I converted the start date to datetime datatype to be able to create a weekday column for my dataset. I also dropped all the null values. I created a new row with only the year which the data was collecte in. All the data was collected in the year 2019. This enabled me to get the members ages by subtracting their birth years from 2019.

# %% [markdown]
# ## Bivariate_Exploration

# %% [markdown]
# ### Relationship between gender and user type

# %%
def bar_chart_solution_7():
    sb.countplot(data = Go_Bike, x = 'user_type', hue = 'member_gender')
    plt.title('Gender Vs. User_Type')
    plt.xlabel('User_Type')
    plt.ylabel('Number of Riders')             
    plt.legend();

bar_chart_solution_7()

# %% [markdown]
# ####  Both customer and subscriber user types are available for all genders. With male subscribers being the most riders.

# %% [markdown]
# ### User type by bike sharing

# %%
Go_Bike['user_type'].groupby(Go_Bike['bike_share_for_all_trip']).value_counts().unstack()
# Out:
# user_type                Customer  Subscriber
# bike_share_for_all_trip
# No                        16566.0    141040.0
# Yes                           NaN     17346.0

# %%
def bar_chart_solution_8():
    Go_Bike['user_type'].groupby(Go_Bike['bike_share_for_all_trip']).value_counts().unstack()
    sb.countplot(data = Go_Bike, x = 'user_type', hue = 'bike_share_for_all_trip')
    plt.title('Bike Sharing Vs. User_Type')
    plt.xlabel('User_Type')
    plt.ylabel('Number of Riders')             
    plt.legend();
bar_chart_solution_8()

# %% [markdown]
# #### Bike sharing is only available for subscriber user type. Most of the subscriber user types do not share their bikes.

# %% [markdown]
# ### Turn up of different genders in different weekdays.

# %%
# Count of riders in each week day
Go_Bike['Day_of_Week'].groupby(Go_Bike['member_gender']).value_counts().unstack()
# Out:
# Day_of_Week    Friday  Monday  Saturday  Sunday  Thursday  Tuesday  Wednesday
# member_gender
# Female           6132    5802      3449    3570      8039     7259       6554
# Male            20951   19304     10653   10613     24945    22763      21271
# Other             580     535       312     329       728      562        601

# %%
def bar_chart_solution_9():
    plt.figure(figsize = [12,5])
    sb.countplot(data = Go_Bike, x = 'Day_of_Week', hue = 'member_gender', order=days_ordered)
    plt.title('Weekday Vs. User_Type')
    plt.xlabel('Weekday')
    plt.ylabel('Number of Riders')             
    plt.legend();

bar_chart_solution_9()

# %% [markdown]
# #### Most of the members turned up on Thusrday for each gender. Saturday had the least number of females turning up than the rest of the week. For males the least turnup was on Sunday.

# %% [markdown]
# ### Was bike sharing common in all days?

# %%
def bar_chart_solution_10():
    plt.figure(figsize = [12,5])
    sb.countplot(data = Go_Bike, x = 'Day_of_Week', hue = 'bike_share_for_all_trip', order = days_ordered)
    plt.title('Weekday Vs. Bike_share')
    plt.xlabel('Weekday')
    plt.ylabel('Number of Riders')  
    plt.legend();
    
bar_chart_solution_10()

# %% [markdown]
# #### Bike share was available in all weekdays.

# %% [markdown]
# ### Relationship between members age and duration

# %%
plt.hist2d(data = Go_Bike, x = 'Members_Age', y = 'duration_sec')
plt.colorbar()
plt.xlabel('Age')
plt.ylabel('Duration(sec)');
plt.title(' Duration Vs. Age');

# %% [markdown]
# #### Riders between 20 - 40 years spend a longer duration of time during riding.

# %% [markdown]
# ### Relationship between duration and Gender

# %%
plt.figure(figsize = [10, 6])
base_color = sb.color_palette()[3]
sb.boxplot(data = Go_Bike, x = 'member_gender', y = 'duration_sec', color = base_color)
plt.ylim([0, 2000])
plt.xlabel('Gender')
plt.ylabel('Duration (sec)')
plt.title(' Duration Vs. Gender')
plt.show();

# %% [markdown]
# #### Females and other ride longer trips than males. With other riding longer trips than females.

# %% [markdown]
# ### Relationship between duration and weekday

# %%
plt.figure(figsize = [10, 6])
base_color = sb.color_palette()[2]
sb.boxplot(data = Go_Bike, x = 'Day_of_Week', y = 'duration_sec', color = base_color, order =days_ordered)
plt.ylim([0, 2000])
plt.xlabel('Weekday')
plt.ylabel('Duration (sec)')
plt.title(' Duration Vs. Weekday')
plt.show();

# %% [markdown]
# ####  Even though most of the rides were made on Thursday the trip made were not the longest.The longest trips were made on Sunday, followed by Saturday, then Friday.
# #### The longest trips were made on weekends.

# %% [markdown]
# ### Relationship between bike sharing and duration.

# %%
plt.figure(figsize = [10, 6])
base_color = sb.color_palette()[2]
sb.boxplot(data = Go_Bike, x = 'bike_share_for_all_trip' , y = 'duration_sec', color = base_color)
plt.ylim([0, 2000])
plt.xlabel('bike_share')
plt.ylabel('Duration (sec)')
plt.title(' Duration Vs. Bike_share')
plt.show();

# %% [markdown]
# ####   For bike sharing, the riders who did not share their bikes had a higher riding duration than those who shared their bikes.

# %% [markdown]
# ### Talk about some of the relationships you observed in this part of the investigation. How did the feature(s) of interest vary with other features in the dataset?
# Subscribers being the most user types, have most males as the user types both in subscriber and customer user types. Riders who are customers are less than subscriber user type for both males and females. For the duration of the trips longer trips were made on weekends(i.e Saturday and Sunday), although more trip were made on Thursday.Bike sharing is only available for subscriber user type. Although bike sharing is only available for subscriber user type, most of the riders do not share the bikes.
# Females and other ride longer trips than males. With other riding longer trips than females.
#
#
#
# ### Did you observe any interesting relationships between the other features (not the main feature(s) of interest)?
#
# Young people spend a higher duration of time during riding than the old people.

# %% [markdown]
# ## Multivariate_Exploration

# %% [markdown]
# ###  Relationship between bike sharing, gender and time duration

# %%
ax = sb.pointplot(data = Go_Bike, x = 'member_gender', y = 'duration_sec', hue = 'bike_share_for_all_trip',
                  dodge = 0.3, linestyles = "")
plt.title('Gender Vs. Duration Vs. Bike_share');

# %% [markdown]
# #### Longer trips are associated with not sharing bikes especially for the other gender. For females those who shared bikes spent more time than those who did not share.

# %%
plt.figure(figsize=[10,5])
sb.violinplot(data = Go_Bike,x='member_gender',y='duration_sec',hue='user_type',inner=None)
plt.xlabel('Gender', labelpad= 40)
plt.ylabel('Duration (Sec)')
plt.title('Duration,  User type and Gender')
plt.legend(title='User_Type', bbox_to_anchor=(1.0,1.5));

# %% [markdown]
# #### For the other gender, customers are the ones with the highest riding duration time. With the other customer user type with the lowest riding duration time. For the male gender both the subscribers and customer users have the same riding duration.

# %% [markdown]
# ### Talk about some of the relationships you observed in this part of the investigation. Were there features that strengthened each other in terms of looking at your feature(s) of interest?
#
# Here in our analysis we have observed that, for other gender customer user type have a higher trip duration compared to male and female gender. Although for the other gender most of them are subsribers.For all the three genders customers have a higher duration time than subscribers.
# For the other gender,  customers are the ones with the highest riding duration time.
#
# ### Were there any interesting or surprising interactions between features?
#
# No

# %% [markdown]
# ## Conclusions
# There are more men than women. Of the total participants in the bike riding, 74.59% were men, 23.32% were female and other was 2.08%.
#
# Most of the members were born between 1985 and 1995.
#
# Bike sharing was not common among the bike riders, with 90.09 % of the riders not sharing the bikes and only 9.91 % sharing the bikes.
#
# All the top 10  start stations are the end stations, except for Bancroft Way at College Avenue. There was a total of 329 start and end stations.
#
#  Bike sharing is only available for subscriber user type. Most of the subscriber user types do not share their bikes.
#  Riders between 20 - 40 years spend a longer duration of time during riding.
#
# Most of the members turned up on Thusrday for each gender. Saturday had the least number of females turning up than the rest of the week. For males the least turnup was on Sunday.
#
# Even though most of the rides were made on Thursday the trips made were not the longest.The longest trips were made on Sunday, followed by Saturday, then Friday. Hence, that leads to the conclusion that the longest trips were made on weekends.
#
# Longer trips are associated with not sharing bikes especially for the other gender. For all the genders, those who shared bikes spent more time than those who did not share.
#
# For bike sharing, the riders who did not share their bikes had a higher riding duration than those who shared their bikes.
# Most of the subscriber  and customer users were men.
#
# All the top 10  start stations are the end stations, except for Bancroft Way at College Avenue. There was a total of 329 start and end stations.
